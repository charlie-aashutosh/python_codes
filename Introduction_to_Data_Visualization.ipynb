# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
from numpy.random import randn

# %%
#creating a dummy dataset
df=pd.DataFrame(randn(1000), index=pd.date_range('2019-06-07', periods=1000),columns=['values'])

# %%
print(df)
# Out:
#               values
# 2019-06-07  0.775340
# 2019-06-08  0.132789
# 2019-06-09  1.018993
# 2019-06-10  0.481658
# 2019-06-11  0.031232
# ...              ...
# 2022-02-26  0.532644
# 2022-02-27 -0.171467
# 2022-02-28  0.601021
# 2022-03-01 -0.788873
# 2022-03-02 -2.391916
#
# [1000 rows x 1 columns]

# %%
df.plot()

# %%
data=pd.DataFrame(np.arange(0,150,10).reshape(3,5), index=["R1","R2","R3"],columns=["C1","C2","C3","C4","C5"])

# %%
print(data)
# Out:
#      C1   C2   C3   C4   C5
# R1    0   10   20   30   40
# R2   50   60   70   80   90
# R3  100  110  120  130  140

# %%
data.plot()

# %%
data_new=pd.read_csv("/content/diabetes.csv")

# %%
data_new.plot()
